# %%
from dotenv import load_dotenv
import os 


load_dotenv()


OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

print(OPENAI_API_KEY)
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# https://smith.langchain.com/o/6459a739-5a87-57df-b2aa-7bf48e50a36b/projects?paginationState=%7B%22pageIndex%22%3A0%2C%22pageSize%22%3A10%7D
# !pip install -qU langchain-teddynote
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("final_model")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# final_model

# %%
# 웹 사이트 URL로 문서 등록
from langchain_community.document_loaders import WebBaseLoader

urls = 'https://www.kita.net/board/overseasMarketNews/overseasMarketNewsDetail.do?postIndex=1839853&boardType=0&ContentsID=KI_overseasMrktNews_01_1839853&query=CSRD'
loader = WebBaseLoader(urls)

# SSL 인증서 오류 우회
loader.requests_kwargs = {"verify": False}

docs = loader.load()

docs
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# c:\Users\kim_h\anaconda3\envs\rag\Lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.kita.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# [Document(page_content='\n\n\n[EU환경규제] 유럽 CSRD에 대하여 2024년에 반드시 알아야 할 것들\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nKITA.NET\n본문으로 이동\n\n\n\n\n\n공지·뉴스\n\n연구·통계·관세\n\n지원·사업\n\n자문·상담\n\n\n멤버십서비스\n국제무역통상연구원\nK-Stat\n\n\n\n\n\n\n\n\n\n\n협회소개\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t홈\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t회장\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t연혁\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t조직소개\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t사업전략/추진과제\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t경영공시\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t윤리경영\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\tCI규정/전용서체\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t채용\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t찾아오시는 길\n\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n검색검색\n\n\n\n\n국내외지부국내외지부\n\n\n국내지역본부\n해외지부\n\n\n\n\n\n로그인로그인\n\n\n로그인\nKITA.net 가입\n회원사 가입\n\n\n\n\n\n\n메일메일\n\n\n\n\nENEN\n\n\n\n\n전체메뉴\n\n\n전체메뉴 닫기\n\n\n\n\n\n메일\n\n검색\n\n메뉴 열기\n\n\n\n\n\n\n\n\n\n\n\n인기메뉴\n\n\n공지사항\n\n\n사업신청\n\n\n증명서발급\n\n\n전문가 1:1 상담\n\n\n보고서\n\n\n\nclose menu\n\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t협회소식\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t공지사항\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t보도자료\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t포토뉴스\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t입찰공고\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n \n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t무역동향\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t무역뉴스\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t뉴스레터\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t해외시장뉴스\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t해외시장동향\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t유관기관뉴스\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n \n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t환율동향\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t환율종합\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t환율뉴스\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n \n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tKITA TV\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n \n \n \n \n \n\n\n\n\n인기메뉴\n\n\n공지사항\n\n\n사업신청\n\n\n증명서발급\n\n\n전문가 1:1 상담\n\n\n보고서\n\n\n\nclose menu\n\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t국제무역통상연구원\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t연구원 소개\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t보고서\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t소부장산업 공급망센터\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t통상뉴스\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t수입규제\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n \n\n\n\ ...

# %%
print(docs[0].page_content[:].replace("\n", ""))
# Out:
# [EU환경규제] 유럽 CSRD에 대하여 2024년에 반드시 알아야 할 것들KITA.NET본문으로 이동공지·뉴스연구·통계·관세지원·사업자문·상담멤버십서비스국제무역통상연구원K-Stat협회소개											홈																					회장																					연혁																					조직소개																					사업전략/추진과제																					경영공시																					윤리경영																					CI규정/전용서체																					채용																					찾아오시는 길										검색검색국내외지부국내외지부국내지역본부해외지부로그인로그인로그인KITA.net 가입회원사 가입메일메일ENEN전체메뉴전체메뉴 닫기메일검색메뉴 열기인기메뉴공지사항사업신청증명서발급전문가 1:1 상담보고서close menu												협회소식																																																												공지사항																																																			보도자료																																																			포토뉴스																																																			입찰공고																																						 												무역동향																																																												무역뉴스																																																			뉴스레터																																																			해외시장뉴스																																																			해외시장동향																																																			유관기관뉴스																																						 												환율동향																																																												환율종합																																																			환율뉴스																																						 												KITA TV																																																	     인기메뉴공지사항사업신청증명서발급전문가 1:1 상담보고서close menu												국제무역통상연구원																																																												연구원 소개																																																			보고서																																																			소부장산업 공급망센터																																																			통상뉴스																																																			수입규제																																						 												무역통계																																																														국내통계																																																			해외통계																																																			IMF 세계통계																																						 최신 업데이트 국가 한국																		24.05 중국																		24.05 일본																		24.04 												관세/규제																									N													관세																																																			규제																																																			FAQ																																						     인기메뉴공지사항사업신청증명서발급전문가 1:1 상담보고서close menu협회사업												사업신청																																																												진행중인 사업																																																			종료된 사업																																																			상시지원 사업																																						 지원/혜택												KITA멤버십																																																														발급																																																			혜택																																																			상담																																																			포상																																																		기업인여행카드 ABTC																																																														자격요건																																																			신규/교체																																																			재발급																																						 												수출역량진단																									N												AI 빅데이터 맞춤분석																																																											스타트업브랜치																																																												스타트업브랜치 소개																																																			KITA Brand 지원사업																																																			공지사항																																																			이벤트																																																			멤버십																																																		이노브랜치																																																	 												디지털 수출지원 센터																																																													해외지부 현지지원																																																											트레이드타워 회의실 임대																																																											수출입 물류포털																																																												물류 동향 및 정보																																																			수출입 물류 매뉴얼																		 ...

# %%
# 예제 문서 
# PDF 문서 로드 및 텍스트 추출
from langchain_community.document_loaders import PyPDFLoader

file_path = "../raw_data/[법률_규범_특허][코트라][2022]한-인도 CEPA 활용법 및 인도 통상 애로.pdf"

loader = PyPDFLoader(file_path, extract_images=False)

docs = loader.load()

# %%
docs[0].page_content
# Out:
# '사례로 정리해보는\n한-인도 CEPA \n활용법 및 인도 통상 애로\nKOTRA자료 22-055'

# %% [markdown]
# ### 0. 모델 선정

# %%
# llm 모델 
from langchain_openai import ChatOpenAI
from config import config

llm = ChatOpenAI(
            model       = config['llm_predictor']['model_name'],            # gpt-3.5-turbo
            temperature = config['llm_predictor']['temperature']            # temperature" : 0
        )

# %% [markdown]
# ### 0. 임베딩 모델 선정

# %%
# 임베딩 모델 
from langchain_openai import OpenAIEmbeddings

from config import config
embeddings_model_OpenAI = OpenAIEmbeddings( model=config['embed_model']['model_name'] )

# %% [markdown]
# ### 0. text_splitter 기법 선정

# %%
# Token 수를 기준으로 문서를 청크 단위로 분할
from langchain_text_splitters import RecursiveCharacterTextSplitter

# text_splitter = RecursiveCharacterTextSplitter()
# 문서를 문장으로 분리
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,            # 1000개의 단어 기준으로 분할을 해주고
    chunk_overlap=10,          # chunk는 100단어가 겹치도록 
)

# %%
# text_splitter로 문서 자르기 
documents = text_splitter.split_documents(docs)

# %% [markdown]
# ### 0. 벡터화 기법 선정

# %%
# # FAISS(Facebook AI Similarity Search)로 문서를 벡터화
# from langchain_community.vectorstores import FAISS

# vector = FAISS.from_documents(documents=documents,
#                               embedding=embeddings_model_KR_SBERT       # embeddings_model_ko_sroberta, embeddings_model_KR_SBERT, embeddings_model_OpenAI
#                               )     

# Chroma를 통한 임베딩 데이터 VectorDB로 저장 

from langchain_community.vectorstores import Chroma


vectorstore = Chroma.from_documents(documents=documents, 
                                    embedding=embeddings_model_OpenAI, # 허깅페이스에 한국어 KR-SBERT 임베딩 모델로 
                                    collection_name="consumer_case_qa",
                                    persist_directory=config["chroma"]["persist_dir"]   # "persist_dir" : "./database",
                                    )    # 로컬의 chroma_db라는 폴더에 저장

# %%
# retriever = vector.as_retriever()
retriever = vectorstore.as_retriever(
            search_kwargs = {"k": config["retriever_k"]},           # 유사도 높은 순으로 가져올 벡터 개수 
            search_type   = "similarity"                            # 유사도 측정 방법 
        )

# %% [markdown]
# ### retrieval이 documents에 잘 접근하는지 확인

# %%
# retriever가 documents에 잘 접근하는지 확인 

'''
해당 pdf파일의 내용 : 나. 인도 DRI(국세정보국) 관세조사 시 대응방안

① 주요 내용
2021년 3월, 철도 신호용 계전기 관련 인도 대법원의 판결(Westinghouse Saxby FarmerLtd. Vs.
Commisioner of Central Excise)에 따라 개별 부품이 자동차의 부품으로 분류될 근거가 됨으로써 인도 국
세정보국(DRI)는 자동차 부품 관련 자의적 해석에 근거한 관세조사를 시행하고 있다. 이로 인해, 인도에 진
출한 관련 기업들의 한-인도 CEPA 활용 불가 및 차액 관세 납부 등의 피해가 발생하고 있다.

'''

# 검색 쿼리
query = "인도 DRI(국세정보국) 관세조사 시 대응방안을 알려주세요."

test_doc = retriever.get_relevant_documents(query)
print(len(test_doc))
print(test_doc[1].page_content)
print(test_doc[1].metadata)
# Out:
# 3
# 나. 인도 DRI(국세정보국) 관세조사 시 대응방안
# 2. 원산지증명서
# 가. 원산지증명서 오류 발급 시 정정 방법
# 나. 원산지증명서 원본 여부 논란 발생 시 대응방안
# {'page': 3, 'source': '../raw_data/[법률_규범_특허][코트라][2022]한-인도 CEPA 활용법 및 인도 통상 애로.pdf'}

# %%
test_doc
# Out:
# [Document(page_content='우, 원산지기준을 모두 충족하여야 한다.\n나. 인도 DRI(국세정보국) 관세조사 시 대응방안\n① 주요 내용', metadata={'page': 6, 'source': '../raw_data/[법률_규범_특허][코트라][2022]한-인도 CEPA 활용법 및 인도 통상 애로.pdf'}),
#  Document(page_content='나. 인도 DRI(국세정보국) 관세조사 시 대응방안\n2. 원산지증명서  \n가. 원산지증명서 오류 발급 시 정정 방법\n나. 원산지증명서 원본 여부 논란 발생 시 대응방안', metadata={'page': 3, 'source': '../raw_data/[법률_규범_특허][코트라][2022]한-인도 CEPA 활용법 및 인도 통상 애로.pdf'}),
#  Document(page_content='추징을 피하기 위한 소송이 가능하지만, 많은 시간과 비용 투입의 부담이 예상되기 때문에 국세정보국(DRI)', metadata={'page': 7, 'source': '../raw_data/[법률_규범_특허][코트라][2022]한-인도 CEPA 활용법 및 인도 통상 애로.pdf'})]

# %%
print(test_doc[0].page_content)
print(test_doc[0].metadata)

# 잘 찾음
# Out:
# 우, 원산지기준을 모두 충족하여야 한다.
# 나. 인도 DRI(국세정보국) 관세조사 시 대응방안
# ① 주요 내용
# {'page': 6, 'source': '../raw_data/[법률_규범_특허][코트라][2022]한-인도 CEPA 활용법 및 인도 통상 애로.pdf'}

# %% [markdown]
# ## 1. 문서와 연결 안된 retriever로 문서 관련 내용 물어보기

# %%
vector_store = Chroma(
            persist_directory=config["chroma"]["persist_dir"],      # "persist_dir" : "./database",
            embedding_function=embeddings_model_OpenAI              # OpenAIEmbeddings( model=config['embed_model']['model_name'] )
        )


from prompt import contextualize_q_prompt, qa_prompt


from langchain.chains import create_history_aware_retriever
# 1. 사용자의 질문 문맥화 -> 대화 히스토리 체인 
history_aware_retriever = create_history_aware_retriever(
                                                        llm, 
                                                        retriever, 
                                                        contextualize_q_prompt          # 사용자 질문 맥락화 프롬프트: 채팅 기록의 맥락을 참조 -> 자연스러운 대화를 위해 
)

from langchain.chains.combine_documents import create_stuff_documents_chain
# 2. 응답 조건 프롬프트 체인 
question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)                    # llm과 응답 조건 프롬프트 체인 

from langchain.chains import create_retrieval_chain
# 3. 최종 체인 생성 : 1과 2를 연결 
rag_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

# %%
question = "안녕?"

rag_chain.invoke(
                {"input": question,
                 "chat_history": [],
                 'context': []
                 }
    )
# Out:
# {'input': '안녕?',
#  'chat_history': [],
#  'context': [],
#  'answer': '안녕하세요! 해외진출에 대해 궁금한 점이 있으신가요? 도와드릴 수 있을까요?'}

# %%
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

store = {}  # 세션 기록을 저장할 딕셔너리
session_histories = {}

# 세션 ID를 기반으로 세션 기록을 가져오는 함수
def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in session_histories:
        session_histories[session_id] = ChatMessageHistory()                            # 새로운 ChatMessageHistory 객체를 생성하여 store에 저장
        print(f"[히스토리 생성] 새로운 히스토리를 생성합니다. 세션 ID: {session_id}")
    return session_histories[session_id]                                                 # 해당 세션 ID에 대한 세션 기록 반환

# %%
# LangChain Expression Language (LCEL)
# RunnableWithMessageHistory 클래스를 사용하여 chain과 메시지 기록을 연결합니다.

from langchain_core.runnables.history import RunnableWithMessageHistory

conversational_rag_chain = RunnableWithMessageHistory(
            rag_chain,                                  # 실행할 Runnable 객체 -> 체인LLM 모델 
            get_session_history,                        # 세션 기록을 가져오는 함수
            input_messages_key="input",                 # 입력 메시지의 키: chain을 invoke() 할때 사용자 쿼리 입력으로 지정하는 key
            history_messages_key="chat_history",        # # 기록 메시지의 키: 대화 기록으로 지정하는 key
            output_messages_key="answer"
        )

# %%
question = "What does 'EU environmental regulations' mean?"

# %%
session_id = 'abc123'

response = conversational_rag_chain.invoke(
            {"input": question},
            config={"configurable": {"session_id": session_id}}
        )
# Out:
# [히스토리 생성] 새로운 히스토리를 생성합니다. 세션 ID: abc123

# %%
response
# Out:
# {'input': "What does 'EU environmental regulations' mean?",
#  'chat_history': [],
#  'context': [],
#  'answer': "'EU environmental regulations' refer to the laws and rules set by the European Union (EU) to protect the environment and promote sustainable practices within its member states. These regulations cover a wide range of environmental issues such as air and water quality, waste management, biodiversity conservation, and climate change mitigation. Companies operating within the EU are required to comply with these regulations to minimize their environmental impact and contribute to a more sustainable future."}

# %%
response["answer"]
# Out:
# "'EU environmental regulations' refer to the laws and rules set by the European Union (EU) to protect the environment and promote sustainable practices within its member states. These regulations cover a wide range of environmental issues such as air and water quality, waste management, biodiversity conservation, and climate change mitigation. Companies operating within the EU are required to comply with these regulations to minimize their environmental impact and contribute to a more sustainable future."

# %%
session_id = 'abc123'
question = "이전 내용을 한글로 답변해 주세요."

response = conversational_rag_chain.invoke(
            {"input": question},
            config={"configurable": {"session_id": session_id}}
        )

# %%
response["answer"]
# Out:
# "'EU 환경 규제'는 유럽 연합(EU)이 회원국 내에서 환경을 보호하고 지속가능한 실천을 촉진하기 위해 정한 법과 규칙을 말합니다. 이러한 규제는 대기와 수질, 폐기물 관리, 생물다양성 보전, 기후 변화 완화 등 다양한 환경 문제를 다룹니다. EU 내에서 활동하는 기업들은 이러한 규정을 준수하여 환경 영향을 최소화하고 더 지속가능한 미래에 기여해야 합니다."
